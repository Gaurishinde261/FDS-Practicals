# %%
import pandas as pd

df=pd.read_csv('HDFC.csv',lines=True)

from scipy.stats import zscore
df['z_score'] = zscore(df['open'])

thereshold = 3
outliers = df[df['z_score'].abs() > threshold]

df_cleaned = df[df['z_score'].abs() <= threshold]

df_cleaned = df_cleaned.drop(columns=['z_score'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df=pd.read_csv('HDFC.csv',lines=True)
#       5 from scipy.stats import zscore
#       6 df['z_score'] = zscore(df['open'])
#
# TypeError: read_csv() got an unexpected keyword argument 'lines'
