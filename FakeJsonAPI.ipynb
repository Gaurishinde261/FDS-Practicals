# %%
import requests as rq
import pandas as pd
api=rq.get("https://fake-json-api.mock.beeceptor.com/companies")
print(api.text)
# Out:
# [
#   {
#     "id": 1,
#     "name": "Predovic - Lynch",
#     "address": "79342 Roberts Crossing",
#     "zip": "52365",
#     "country": "Saint Kitts and Nevis",
#     "employeeCount": 7520,
#     "industry": "Technology",
#     "marketCap": 2261619167,
#     "domain": "critical-scratch.biz",
#     "logo": "https://example.com/logo1.png",
#     "ceoName": "Jakob Lemke"
#   },
#   {
#     "id": 2,
#     "name": "Schaden, Schuster and Wiegand",
#     "address": "660 Harvey Passage",
#     "zip": "50346-0656",
#     "country": "Romania",
#     "employeeCount": 7926,
#     "industry": "Technology",
#     "marketCap": 6894471435,
#     "domain": "brown-solvency.biz",
#     "logo": "https://example.com/logo1.png",
#     "ceoName": "Don Harvey"
#   },
#   {
#     "id": 3,
#     "name": "Beahan and Sons",
#     "address": "682 Windmill Close",
#     "zip": "69274",
#     "country": "Venezuela",
#     "employeeCount": 2406,
#     "industry": "Technology",
#     "marketCap": 5976490146,
# ...

# %%
api.json()
# Out:
# [{'id': 1,
#   'name': 'Collier - Hills',
#   'address': '7687 N Franklin Street',
#   'zip': '35471',
#   'country': 'Niger',
#   'employeeCount': 226,
#   'industry': 'Technology',
#   'marketCap': 4625216979,
#   'domain': 'perky-strategy.biz',
#   'logo': 'https://example.com/logo1.png',
#   'ceoName': 'Nick Stark'},
#  {'id': 2,
#   'name': 'Nader - Schmidt',
#   'address': '381 Andreane Knoll',
#   'zip': '69767',
#   'country': 'Bosnia and Herzegovina',
#   'employeeCount': 62,
#   'industry': 'Technology',
#   'marketCap': 6507246877,
#   'domain': 'stunning-flood.net',
#   'logo': 'https://example.com/logo1.png',
#   'ceoName': 'Claude Hane-Lemke'},
#  {'id': 3,
#   'name': 'Wuckert LLC',
#   'address': '5506 Nienow Flats',
#   'zip': '33971-0133',
#   'country': 'Estonia',
#   'employeeCount': 1459,
#   'industry': 'Technology',
#   'marketCap': 8408260889,
#   'domain': 'whole-edge.name',
#   'logo': 'https://example.com/logo1.png',
#   'ceoName': 'Joany Cassin'},
# ...

# %%
df=pd.DataFrame(api)
print(df)
# Out:
#                                                     0
# 0   b'[\n  {\n    "id": 1,\n    "name": "Predovic ...
# 1   b'Saint Kitts and Nevis",\n    "employeeCount"...
# 2   b'tical-scratch.biz",\n    "logo": "https://ex...
# 3   b'"Schaden, Schuster and Wiegand",\n    "addre...
# 4   b'ployeeCount": 7926,\n    "industry": "Techno...
# 5   b'https://example.com/logo1.png",\n    "ceoNam...
# 6   b'"682 Windmill Close",\n    "zip": "69274",\n...
# 7   b'   "marketCap": 5976490146,\n    "domain": "...
# 8   b'Kuhic"\n  },\n  {\n    "id": 4,\n    "name":...
# 9   b'thuania",\n    "employeeCount": 3610,\n    "...
# 10  b'    "logo": "https://example.com/logo1.png",...
# 11  b'd Rau",\n    "address": "342 Washington Road...
# 12  b'y": "Technology",\n    "marketCap": 27661879...
# 13  b'",\n    "ceoName": "Katelyn Flatley"\n  },\n...
# 14  b' "zip": "52461-3747",\n    "country": "Mongo...
# 15  b'5818,\n    "domain": "aged-joy.org",\n    "l...
# ...
