# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_json('titanicparquet.json',lines=True)


column = 'Age'

q1 = df[column].quantile(0.25)
q3 = df[column].quantile(0.75)
IQR = q3 - q1

lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR

uncleaned_df = df[(df[column] < lower_bound) | (df[column] > upper_bound)]

cleaned_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

plt.title('Uncleaned Data')
plt.boxplot(uncleaned_df[column])
plt.show()

# %%
from scipy.stats import zscore
df['z_score'] = zscore(df['your_column'])

thereshold = 3
outliers = df[df['z_score'].abs() > threshold]

df_cleaned = df[df['z_score'].abs() <= threshold]

df_cleaned = df_cleaned.drop(columns=['z_score'])
